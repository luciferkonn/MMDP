# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mmdp import mqlearning
import argparse
from grid_city import GridWorld
ROOT = '/home/jikunkang/Git/MMDP/'

# %%
import sys
sys.argv=['']; del sys
parser = argparse.ArgumentParser(description='Multi-agent DDPG')
# add argument
parser.add_argument('--grid_size', default=100, type=int, help='the size of a grid world')
parser.add_argument('--n_actions', default=5, type=int, help='total number of actions an agent can take')
parser.add_argument('--filename', default=ROOT+'/data/pr.txt', type=str, help='Pick-up probability file')
parser.add_argument('--n_agents', default=1, type=int, help='the number of agent play in the environment')
parser.add_argument('--runs', default=5, type=int, help='the number of times run the game')
# parser args
args = parser.parse_args()

# %%
env1 = GridWorld(args=args, terminal_time=1000, reward_stay=-1, reward_hitwall=-2, reward_move=-1, reward_pick=2)
rewards4_1, q_value = mqlearning(args=args, env=env1, episode_len=30000, runs=args.runs, epsilon=0.1)
rewards4_1 /= args.runs
# Out:
# RUNS:0
# Episode:0, reward711
# Episode:10, reward586
# Episode:20, reward446
# Episode:30, reward622
# Episode:40, reward858
# Episode:50, reward1448
# Episode:60, reward992
# Episode:70, reward-1000
# Episode:80, reward-1000
# Episode:90, reward1026
# Episode:100, reward-1000
# Episode:110, reward-1000
# Episode:120, reward-1001
# Episode:130, reward-1000
# Episode:140, reward-142
# Episode:150, reward-1001
# Episode:160, reward536
# Episode:170, reward565
# Episode:180, reward-1000
# Episode:190, reward770
# Episode:200, reward-1023
# Episode:210, reward-1000
# Episode:220, reward864
# Episode:230, reward-1006
# Episode:240, reward-1000
# Episode:250, reward-1000
# Episode:260, reward602
# Episode:270, reward-856
# Episode:280, reward-1000
# Episode:290, reward-547
# Episode:300, reward-1007
# Episode:310, reward-547
# Episode:320, reward551
# Episode:330, reward-1024
# Episode:340, reward-1002
# Episode:350, reward-1006
# Episode:360, reward760
# Episode:370, reward83
# Episode:380, reward-1000
# Episode:390, reward635
# Episode:400, reward1226
# Episode:410, reward1196
# Episode:420, reward-1007
# Episode:430, reward782
# Episode:440, reward1331
# Episode:450, reward785
# Episode:460, reward-1006
# Episode:470, reward-1006
# Episode:480, reward263
# Episode:490, reward1439
# Episode:500, reward1019
# Episode:510, reward1457
# Episode:520, reward8
# Episode:530, reward-1007
# Episode:540, reward71
# Episode:550, reward-1000
# Episode:560, reward1367
# Episode:570, reward611
# Episode:580, reward1268
# Episode:590, reward914
# Episode:600, reward-418
# Episode:610, reward1238
# Episode:620, reward926
# Episode:630, reward-916
# Episode:640, reward1328
# Episode:650, reward-169
# Episode:660, reward1022
# Episode:670, reward1457
# Episode:680, reward818
# Episode:690, reward1193
# Episode:700, reward-280
# Episode:710, reward1025
# Episode:720, reward1340
# Episode:730, reward-316
# Episode:740, reward1721
# Episode:750, reward-1005
# Episode:760, reward-1008
# Episode:770, reward1334
# Episode:780, reward1112
# Episode:790, reward1391
# Episode:800, reward1208
# Episode:810, reward-1000
# Episode:820, reward756
# Episode:830, reward1226
# Episode:840, reward866
# Episode:850, reward1316
# Episode:860, reward-1004
# Episode:870, reward1424
# Episode:880, reward-1007
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-683d3bc8d07c> in <module>()
#       1 env1 = GridWorld(args=args, terminal_time=1000, reward_stay=-1, reward_hitwall=-2, reward_move=-1, reward_pick=2)
# ----> 2 rewards4_1, q_value = mqlearning(args=args, env=env1, episode_len=30000, runs=args.runs, epsilon=0.1)
#       3 rewards4_1 /= args.runs
#
# ~/Git/MMDP/mmdp/mmdp.py in mqlearning(args, env, episode_len, learning_rate, epsilon, gamma, runs)
#      41                         # print(action[j])
#      42                 # every agent take a step
# ---> 43                 next_state, reward, done, info = env.step(action)
#      44
#      45                 # find the others actions
#
# ~/Git/MMDP/mmdp/grid_city.py in step(self, action)
#      50         self.time += 1
#      51
# ---> 52         self.make_move(action)
#      53         # return for each agent
#      54         for i, agent in enumerate(self.agents):
#
# ~/Git/MMDP/mmdp/grid_city.py in make_move(self, action)
#     141                         else:
#     142                             cust_prob = self.cust_prob
# --> 143                         if self.can_pick(x, y, cust_prob):
#     144                             agent.reward = self.reward_pick
#     145                             agent.step['event'] = 'pick'
#
# ~/Git/MMDP/mmdp/grid_city.py in can_pick(self, x, y, cust_prob)
#     180     # check if a car agent can find a passenger at location(x, y)
#     181     def can_pick(self, x, y, cust_prob):
# --> 182         return np.random.binomial(1, cust_prob[x][y])
#     183
#     184     # give every grid(x, y) a pick up probability from pr.txt
#
# KeyboardInterrupt:

# %%
env2 = GridWorld(args=args, terminal_time=1000, reward_stay=-1, reward_hitwall=-2, reward_move=-1, reward_pick=2, aggre=True)
rewards4_2, q_value = mqlearning(args=args, env=env2, episode_len=300, runs=args.runs, learning_rate=1, epsilon=0.1, gamma=0.9)
rewards4_2 /= args.runs

# %%
# rewards1 = rewards4_1
# rewards2 = rewards4_2
plt.figure(1)
plt.plot(rewards1[:29999], label='Heuristic without Aggregation', linewidth=1)
# plt.plot(rewards2, label='Heuristic with Average Pooling', linewidth=1)
# plt.plot(rewards3, label='Multi-agent Q-Learning', linewidth=1)

plt.xlabel('episode')
plt.ylabel('mean episode reward')
plt.legend()
# plt.title('10*10 Grid World 4 agents')
# plt.savefig('three_compare', dpi=None, facecolor='w', edgecolor='w',
#         orientation='portrait', papertype=None, format=None,
#         transparent=False, bbox_inches=None, pad_inches=0.1,
#         frameon=None)
plt.show()

# %%
from scipy.interpolate import interp1d
x = np.linspace(0, 30000, num=30000, endpoint=True)
#用3次多项式拟合  
# f2 = np.polyfit(x, rewards2, 30)  
# p2 = np.poly1d(f2)
f1 = np.polyfit(x, rewards1[:30000], 60)
p1 = np.poly1d(f1)
# f3 = np.polyfit(x, rewards3, 30)
# p3 = np.poly1d(f3)
  
#也可使用yvals=np.polyval(f1, x)  
# yvals2 = p2(x)  #拟合y值
yvals1 = p1(x)
# yvals3 = p3(x)

plt.figure(2)
plt.plot(x, yvals1, label='Multi-agent Q-Learning', linewidth=1)
# plt.plot(x, yvals2, label='Heuristic with Average Pooling', linewidth=1)
plt.xlabel('episode')
plt.ylabel('mean episode reward')
plt.legend()
# plt.title('10*10 Grid World 4 agents')
plt.savefig('5*5_7_agents', dpi=None, facecolor='w', edgecolor='w',
        orientation='portrait', papertype=None, format=None,
        transparent=False, bbox_inches=None, pad_inches=0.1,
        frameon=None)
plt.show()
# Out:
# /home/jikunkang/anaconda3/lib/python3.6/site-packages/numpy/lib/polynomial.py:583: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# /home/jikunkang/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:32: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims)
# /home/jikunkang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: RankWarning: Polyfit may be poorly conditioned

# %%
from scipy.interpolate import interp1d
x = np.linspace(0, 30000, num=30000, endpoint=True)
#用3次多项式拟合  
# f2 = np.polyfit(x, rewards2, 30)  
# p2 = np.poly1d(f2)
f1 = np.polyfit(x, rewards1, 30)
p1 = np.poly1d(f1)
# f3 = np.polyfit(x, rewards3, 30)
# p3 = np.poly1d(f3) 
sigma = 0.01
#也可使用yvals=np.polyval(f1, x)  
# yvals2 = p2(x)  #拟合y值
yvals1 = p1(x)
# yvals3 = p3(x)

# Upper bound and Lower bound
lower_bound1 = yvals1 - 50
upper_bound1 = yvals1 + 50

# lower_bound2 = yvals2 - 50
# upper_bound2 = yvals2 + 50

# lower_bound3 = yvals3 - 50
# upper_bound3 = yvals3 + 50

fig, ax = plt.subplots(1)
ax.plot(x, yvals1, label='one agent optimal policy', linewidth=1)
# ax.plot(x, yvals2, label='Heuristic with Average Pooling', linewidth=1)
# ax.plot(x, yvals3, label='Multi-agent Q-Learning', linewidth=1)

ax.fill_between(x, lower_bound1, upper_bound1, facecolor='purple', alpha=0.5)
# ax.fill_between(x, lower_bound2, upper_bound2, facecolor='orange', alpha=0.5)
# ax.fill_between(x, lower_bound3, upper_bound3, facecolor='green', alpha=0.5)

ax.set_xlabel('episode')
ax.set_ylabel('mean episode reward')
ax.legend()
ax.grid()
fig.savefig('20*20_1_agents', dpi=None, facecolor='w', edgecolor='w',
        orientation='portrait', papertype=None, format=None,
        transparent=False, bbox_inches=None, pad_inches=0.1,
        frameon=None)
# Out:
# /home/jikunkang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: RankWarning: Polyfit may be poorly conditioned

# %%
with open('5*5_1_q_value.txt', 'w') as outfile:
    for slice_2d in q_value:
        np.savetxt(outfile, slice_2d)

# %%
rewards1 = np.loadtxt('20*20_1_agents.txt')

# %%
rewards2= [-299.92, -203.36, -25.2 , 75.36, 169.28,  256.72, 297.6 , 224.96,
       269.68, 209.44, 218.88, 235.76, 262.16, 298.48, 221.2 , 341.84,
       422.64, 409.36, 415.92, 335.04, 280.  , 370.96, 400.24, 348.4 ,
       392.16, 367.92, 420.4 , 423.68, 372.8 , 364.4 , 366.64, 297.44,
       310.56, 380.16, 359.68, 354.96, 397.2 , 305.12, 362.16, 367.04,
       391.68, 428.16, 410.72, 383.76, 407.2 , 365.92, 376.72, 409.68,
       362.56, 341.52, 332.48, 354.48, 450.56, 370.  , 292.56, 312.72,
       364.64, 377.2 , 334.96, 345.04, 391.84, 416.64, 370.96, 336.16,
       381.2 , 377.36, 347.84, 378.72, 317.52, 411.84, 405.52, 387.2 ,
       362.48, 361.84, 361.76, 386.4 , 367.12, 301.44, 346.64, 357.2 ,
       384.64, 463.68, 401.04, 384.32, 400.96, 388.16, 354.08, 480.48,
       426.48, 471.28, 435.28, 535.36, 441.2 , 479.12, 466.4 , 404.64,
       366.64, 454.4 , 379.12, 406.88, 407.36, 438.8 , 491.2 , 456.88,
       488.  , 421.36, 519.2 , 538.56, 410.08, 456.16, 470.88, 439.44,
       539.12, 486.56, 470.08, 478.88, 472.64, 499.52, 513.44, 505.52,
       524.8 , 426.32, 518.64, 462.72, 458.32, 512.72, 442.4 , 448.4 ,
       414.88, 452.88, 422.08, 414.96, 420.72, 407.28, 424.8 , 417.52,
        -89.36, -122.24,  -62.78,  -81.08,  -83.44,  -94.68,  -67.94,
       -102.1 , -103.52,  -97.1 , -113.46, -108.72, -118.58, -103.02,
       -106.92, -125.68, -127.36,  -98.36, -140.84, -115.62, -117.28,
        -74.16,  -93.4 , -119.02, -100.2 , -116.16, -121.74,  -96.86,
        -89.98,  -67.96, -111.64,  -56.34,  -66.26,  -68.36,  -90.58,
        -99.38,  -14.48, -145.18, -113.24,  -88.26,  -74.28,  -96.06,
        -82.66, -100.76, -125.06, -113.22,  -90.48,  -92.98, -102.4 ,
        -79.12, -143.54, -135.52,  -95.88, -103.98,  -93.7 , -138.58,
        -75.46, -135.82, -125.78,  -97.86,  -92.26, -128.94, -117.14,
        -79.96, -115.16,  -86.18,  -75.06,  -68.98,  -65.24,  -36.92,
        -71.64,  -73.24, -105.88,  -70.54, -101.18,  -81.32, -107.16,
        -89.02,  -80.2 , -120.02, -115.12,  -67.32,  -80.46, -114.08,
        -72.54, -108.24, -137.22, -132.78, -107.94,  -85.88, -121.14,
       -101.62,  -72.52,  -85.96,  -78.64,  -47.38,  -35.38,  -64.04,
       -106.44, -120.24, -114.88,  -76.52, -102.54,  -99.36,  -38.1 ,
        -81.36,  -74.22,  -71.02,  -85.08,  -32.26,  -78.84,  -96.78,
       -127.  ,  -84.88,  -59.1 ,  -64.3 ,  -77.68,  -94.14,  -71.34,
        -60.54,  -75.14,  -50.12,  -58.32,  -72.22,  -40.9 ,  -78.  ,
        -64.04,  -61.84,  -72.36, -114.32,  -64.7 , -105.02, -112.16,
        -59.84,  -86.72, -102.22,  -87.3 ,  -74.2 ,  -82.64,  -71.44,
        -78.46,  -82.74,  -56.5 ,  -63.16,  -92.58,  -51.26,  -43.62,
        -42.16,  -89.9 , -115.22,  -56.6 ,  -20.84,  -47.52,  -30.46,
        -53.8 ,  -54.22,   -9.16,  -51.98,  -85.04,  -30.5 ,  -62.44,
        -72.22,  -75.98,  -52.02,  -68.3 ,  -52.04,  -74.64,  -76.76,
       -100.2 ,  -53.44,  -65.22,  -57.88,  -69.62, -106.98,  -73.76,
       -115.42,  -79.24,  -51.8 ,  -77.16,  -78.52,  -95.42,  -25.7 ,
        -46.24,  -21.72,  -89.86, -116.68,  -98.86,  -20.88,  -73.26,
         -1.56,  -32.68,  -57.96,  -73.68,  -74.78,  -62.36,  -33.96,
        -47.96, -109.66,  -30.46,  -95.82,  -74.28,  -83.38,  -97.38,
        -40.6 ,  -38.52,  -65.52, -145.88,  -68.16,  -79.06,  -72.16,
        -95.06,  -31.22,  -77.2 ,  -68.62,   -6.6 ,  -63.62,  -79.72,
        -89.98,  -71.74,  -73.4 ,  -21.  ,  -41.78, -113.52]

# %%
np.savetxt('100*100_6_agents.txt', rewards1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6e5d4ec4fa41> in <module>()
# ----> 1 np.savetxt('100*100_6_agents.txt', rewards1)
#
# NameError: name 'rewards1' is not defined

# %%
rewards1
# Out:
# array([-3056. , -2607. , -2835.2, ..., -2786.6, -3193.2, -3537.6])
